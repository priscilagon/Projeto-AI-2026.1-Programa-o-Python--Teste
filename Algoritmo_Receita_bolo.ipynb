# %% [markdown]
# <a href="https://colab.research.google.com/github/priscilagon/Projeto-AI-2026.1-Programa-o-Python--Teste/blob/main/Algoritmo_Receita_bolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time # Biblioteca para simular o tempo passando

# %%
print("--- INICIANDO O ALGORITMO DO BOLO ---")
# Out:
# --- INICIANDO O ALGORITMO DO BOLO ---

# %%
# 1. Variáveis: Separando os ingredientes e ferramentas
temperatura_forno = 0
forma_untada = True
tigela = [] # Uma lista vazia para colocar os ingredientes
massa_homogenea = False
tempo_de_forno = 40
palito_limpo = False

# %%
# 2. Entrada/Ações Simples
print("\nPasso 1: Ligando o forno...")
temperatura_forno = 180
print(f"Forno aquecido a {temperatura_forno}°C.")

print("\nPasso 2: Adicionando ingredientes na tigela...")
tigela.append("ovos")
tigela.append("açúcar")
tigela.append("farinha")
tigela.append("leite")
print(f"Ingredientes na tigela: {tigela}")
# Out:
# Passo 1: Ligando o forno...
# Forno aquecido a 180°C.
#
# Passo 2: Adicionando ingredientes na tigela...
# Ingredientes na tigela: ['ovos', 'açúcar', 'farinha', 'leite']

# %%
# 2. Entrada/Ações Simples
print("\nPasso 1: Ligando o forno...")
temperatura_forno = 180
print(f"Forno aquecido a {temperatura_forno}°C.")

print("\nPasso 2: Adicionando ingredientes na tigela...")
tigela.append("ovos")
tigela.append("açúcar")
tigela.append("farinha")
tigela.append("leite")
print(f"Ingredientes na tigela: {tigela}")
# Out:
# Passo 1: Ligando o forno...
# Forno aquecido a 180°C.
#
# Passo 2: Adicionando ingredientes na tigela...
# Ingredientes na tigela: ['ovos', 'açúcar', 'farinha', 'leite', 'ovos', 'açúcar', 'farinha', 'leite']

# %%
# 4. Ação: Colocar no forno
if forma_untada:
    print("\nPasso 4: Despejando a massa na forma untada e colocando no forno.")
else:
    print("\nERRO: A forma não está untada! O bolo vai grudar.")
# Out:
# Passo 4: Despejando a massa na forma untada e colocando no forno.

# %%
# 5. Estrutura Condicional (If/Else): O teste do palito
print(f"\nPasso 5: Assando por {tempo_de_forno} minutos...")
time.sleep(2) # Simulando o tempo de forno

print("Apita o alarme! Hora de fazer o teste do palito.")

# Simulando o teste (você pode mudar palito_limpo para True ou False para mostrar aos alunos)
palito_limpo = True

if palito_limpo == True:
    print("Resultado: O palito saiu limpo!")
    print("Ação: Tirar o bolo do forno e desligar o fogo.")
else:
    print("Resultado: O palito saiu sujo de massa.")
    print("Ação: Deixar no forno por mais 5 minutos.")

print("\n--- FIM DO PROGRAMA: BOLO PRONTO! ---")
# Out:
# Passo 5: Assando por 40 minutos...
# Apita o alarme! Hora de fazer o teste do palito.
# Resultado: O palito saiu limpo!
# Ação: Tirar o bolo do forno e desligar o fogo.
#
# --- FIM DO PROGRAMA: BOLO PRONTO! ---
